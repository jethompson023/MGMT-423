# %% [markdown]
# <a href="https://colab.research.google.com/github/jethompson023/MGMT-423/blob/main/Assignment1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# As individuals, create a Jupyter notebook in Google Colab to import the data from the SalaryData.csv file attached below.  Use the pandas and matplotlib.pyplot libraries.
#                import pandas as pd
#                import matplotlib.pyplot as plt
# M
# ake sure to pull a copy of the csv to your own Google Drive so you can open it from there.
#
# Create a scatterplot of Salary against Years of Experience and submit the file by sharing.  Easy to find help on the internet (or look up coding examples in our textbook).

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

worksheet = gc.open('SalaryData').sheet1

#get_all_values gives a list of rows
rows = worksheet.get_all_values()

# %%
#Convert to a DataFrame and render
import pandas as pd
df = pd.DataFrame.from_records(rows)
df.columns = df.iloc[0]
df = df[1:]
df.head()
# Out:
# 0 YearsExperience Salary
# 1             1.1  39343
# 2             1.3  46205
# 3             1.5  37731
# 4               2  43525
# 5             2.2  39891

# %%
import matplotlib.pyplot as plt

# plt.scatter(df.YearsExperience, df.Salary)

# x = df.YearsExperience
# y = df.Salary

#create scatterplot
df.plot.scatter(x='YearsExperience', y='Salary')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>
